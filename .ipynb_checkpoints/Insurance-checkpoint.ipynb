# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --db uk_food --collection establishments --file establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
# List the databases
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'data_json', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['data_json']

# %%
# review the collections in our new database
# List the collections in the uk_food database
print(db.list_collection_names())
# Out:
# ['project3']

# %%
# review the collections in our new database
# Retrieve and display one document from the establishments collection
collection = db["project3"]
document = collection.find_one()
pprint(document)
# Out:
# {'_id': ObjectId('64b6df71c56ffe4e4587ada0'),
#  'data': [['row-vd63_pdas_uhrc',
#            '00000000-0000-0000-FA53-75E94C628D83',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'ALLEGANY',
#            '29'],
#           ['row-shx5~ypqx.idhw',
#            '00000000-0000-0000-28A4-B22D7244A15C',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'ANNE ARUNDEL',
#            '1587'],
#           ['row-nzm3-425r-yuu9',
#            '00000000-0000-0000-2ED5-7EECEED341F3',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'BALTIMORE',
#            '1508'],
#           ['row-utir_n3gr~ed5y',
#            '00000000-0000-0000-52C4-1A1F663165A2',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'BALTIMORE CITY',
#            '770'],
#           ['row-mbbd-8xvu_53d6',
#            '00000000-0000-0000-ABAD-B081F9A274B3',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'CALVERT',
#            '140'],
#           ['row-59jr.p93b~gzhs',
#            '00000000-0000-0000-67EB-98994B9AD4BC',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'CAROLINE',
#            '8'],
#           ['row-p8me-mxxu~nj2s',
#            '00000000-0000-0000-C113-DB47FDC40266',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'CARROLL',
#            '292'],
#           ['row-b8b5.9379.pcrt',
#            '00000000-0000-0000-8D0F-597939A0A5EE',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'CECIL',
#            '82'],
#           ['row-r7z2~a5gu~b4uh',
#            '00000000-0000-0000-1470-E8CA85EB8F47',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'CHARLES',
#            '197'],
#           ['row-72tw~btt5~x7mx',
#            '00000000-0000-0000-DF7C-19B53C8BB1B7',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'DORCHESTER',
#            '24'],
#           ['row-uxgq.mab2.ujha',
#            '00000000-0000-0000-E027-793396FE6A53',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'FREDERICK',
#            '710'],
#           ['row-5rpb_tp28~veye',
#            '00000000-0000-0000-A896-32C088F88278',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'GARRETT',
#            '15'],
#           ['row-hfxx.z3iz-8ufc',
#            '00000000-0000-0000-C2E4-65E15B86CED9',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'HARFORD',
#            '321'],
#           ['row-taqu.ts3g-xd7g',
#            '00000000-0000-0000-5AD4-45F2610521BC',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'HOWARD',
#            '1934'],
#           ['row-9m5c-iww8_etjb',
#            '00000000-0000-0000-B1E7-A4391FD2FF5D',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'KENT',
#            '15'],
#           ['row-6mam-yjmy-4mgi',
#            '00000000-0000-0000-1665-C47015929C40',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'MONTGOMERY',
#            '5791'],
#           ['row-79tz.ssn8.8ydh',
#            '00000000-0000-0000-676D-5732F1935FCD',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'PRINCE GEORGES',
#            '1208'],
#           ['row-6wk4-ngtj_3avw',
#            '00000000-0000-0000-3740-234E820F83BC',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'QUEEN ANNES',
#            '84'],
#           ['row-i8y2.vnfy-27xb',
#            '00000000-0000-0000-BADF-F3A6162EBD8E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'SAINT MARYS',
#            '144'],
#           ['row-z4n2_ccxg.rt3h',
#            '00000000-0000-0000-A9F9-4A85A9480789',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'SOMERSET',
#            '2'],
#           ['row-kp5n~vk9f_bwk9',
#            '00000000-0000-0000-C8AA-1D834AD0EDA8',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'TALBOT',
#            '68'],
#           ['row-c3ww~uw7z~puwt',
#            '00000000-0000-0000-7A84-022377C61243',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'UNKNOWN',
#            '28'],
#           ['row-seha_4a9s.nxtu',
#            '00000000-0000-0000-F222-1E28B06ED911',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'WASHINGTON',
#            '136'],
#           ['row-jetf.vjxe~ytsc',
#            '00000000-0000-0000-E480-656862362998',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'WICOMICO',
#            '50'],
#           ['row-br6v~g9nx_dgpq',
#            '00000000-0000-0000-A7E3-809EE56FE2EB',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'WORCESTER',
#            '46'],
#           ['row-pbx6~dis5_nyme',
#            '00000000-0000-0000-288D-6034C86B55B6',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'CA',
#            '2'],
#           ['row-x5yw~mmdu-88p5',
#            '00000000-0000-0000-D90C-C5663514D828',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Electric',
#            'TX',
#            '1'],
#           ['row-ne3p~hav3.5xqt',
#            '00000000-0000-0000-3D15-08EDFB88D171',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'ALLEGANY',
#            '32'],
#           ['row-szzv~vf6m.p5xq',
#            '00000000-0000-0000-2065-8E9744DF7991',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'ANNE ARUNDEL',
#            '1124'],
#           ['row-8ri3-gscj~hmh7',
#            '00000000-0000-0000-6FBA-9287FD422845',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'BALTIMORE',
#            '1230'],
#           ['row-2imy~gb5m-evxc',
#            '00000000-0000-0000-E8FF-F229519E121A',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'BALTIMORE CITY',
#            '585'],
#           ['row-sg3x.m6pa-5ukk',
#            '00000000-0000-0000-D026-DA28EBCB68D0',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'CALVERT',
#            '160'],
#           ['row-rg5r-d63c-bag6',
#            '00000000-0000-0000-4F3B-5E6F3CAFB6F4',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'CAROLINE',
#            '19'],
#           ['row-x2t5_apyi~grs5',
#            '00000000-0000-0000-053C-5C945B17A4DE',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'CARROLL',
#            '231'],
#           ['row-mknz_2wak-9bzj',
#            '00000000-0000-0000-F056-D142F5FDFCD7',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'CECIL',
#            '74'],
#           ['row-r2kc.tkcn-f54a',
#            '00000000-0000-0000-6DC4-879C09FE8938',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'CHARLES',
#            '172'],
#           ['row-agrq~xsar~3psg',
#            '00000000-0000-0000-FA1F-EAD6A7957C28',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'DORCHESTER',
#            '26'],
#           ['row-ffz4.3ns8~ecxj',
#            '00000000-0000-0000-35F3-5CFC21B7705E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'FREDERICK',
#            '700'],
#           ['row-gj22.7ggd~3vne',
#            '00000000-0000-0000-F0B0-7438A9124B2B',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'GARRETT',
#            '5'],
#           ['row-igyz_5zpk_n2u6',
#            '00000000-0000-0000-78D0-A2EF369F70F0',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'HARFORD',
#            '281'],
#           ['row-k5br~sf3h_pb2h',
#            '00000000-0000-0000-C34F-720D285E4AE6',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'HOWARD',
#            '1150'],
#           ['row-9jwd.hr85.ycdx',
#            '00000000-0000-0000-0646-BD23B56F7FFE',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'KENT',
#            '31'],
#           ['row-56gj.2gd2.7v5y',
#            '00000000-0000-0000-7A96-1F8008CE1FF9',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'MONTGOMERY',
#            '3583'],
#           ['row-5wfu.d2k2_w9k3',
#            '00000000-0000-0000-B2A1-F286E096B3B1',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'PRINCE GEORGES',
#            '938'],
#           ['row-wqrb_9m3a_x2ip',
#            '00000000-0000-0000-A28E-F9EAF1C230CA',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'QUEEN ANNES',
#            '82'],
#           ['row-xfqc~yduu-jx9h',
#            '00000000-0000-0000-7DF6-DC9B87F468F6',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'SAINT MARYS',
#            '174'],
#           ['row-9vsr.hqci-vhh7',
#            '00000000-0000-0000-BF69-9D89853BC2BB',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'SOMERSET',
#            '7'],
#           ['row-wtqk-7zw2.qw4b',
#            '00000000-0000-0000-272C-008A7BCAFB3F',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'TALBOT',
#            '85'],
#           ['row-68cq-3ejb~zztx',
#            '00000000-0000-0000-32A9-F3A21B028DAF',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'UNKNOWN',
#            '18'],
#           ['row-x2xz.ni4j.v25s',
#            '00000000-0000-0000-043D-5B3AEE645018',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'WASHINGTON',
#            '163'],
#           ['row-9uxd~ffcf.hx8e',
#            '00000000-0000-0000-D922-E5054066E167',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'WICOMICO',
#            '82'],
#           ['row-w8f9.f4up~dwdc',
#            '00000000-0000-0000-1A43-5CB8ABB254C9',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'WORCESTER',
#            '62'],
#           ['row-iwut.ir37.5t8u',
#            '00000000-0000-0000-09B5-D96A761FAC41',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'CO',
#            '2'],
#           ['row-xx89-scvf_jbnf',
#            '00000000-0000-0000-36C6-B770B42CBE51',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'DE',
#            '1'],
#           ['row-aagh.d72w~4nga',
#            '00000000-0000-0000-DDD0-58D66A1256DE',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'GA',
#            '1'],
#           ['row-i3eq_6jfc~yvfq',
#            '00000000-0000-0000-03C8-950D04AA0DCB',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'IL',
#            '1'],
#           ['row-iqgd.qsqq_z5x6',
#            '00000000-0000-0000-4BFD-486918D4B009',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'KY',
#            '1'],
#           ['row-qye9_qpgj~y59t',
#            '00000000-0000-0000-61CE-5AEB1794DBBC',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'NC',
#            '1'],
#           ['row-qhdw_iki3-ycfv',
#            '00000000-0000-0000-51D7-7BC4E745C8B8',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'OH',
#            '3'],
#           ['row-w7cz.gddn~2c43',
#            '00000000-0000-0000-C33D-41BDBB98E3BD',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'TN',
#            '1'],
#           ['row-etm4_njye-7wbf',
#            '00000000-0000-0000-8798-0B9D7FCAD90B',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/07',
#            'Plug-in Hybrid',
#            'WA',
#            '1'],
#           ['row-pwwk~f6pv_hxtv',
#            '00000000-0000-0000-9551-CCD702CAEC16',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'ALLEGANY',
#            '32'],
#           ['row-3ij5.7vk4~brnf',
#            '00000000-0000-0000-58C8-6AC8A8081ED3',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'ANNE ARUNDEL',
#            '1625'],
#           ['row-q96g~9gms~hqpp',
#            '00000000-0000-0000-3949-745F8C29B52B',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'BALTIMORE',
#            '1549'],
#           ['row-kfve~223m~mspp',
#            '00000000-0000-0000-FE4F-E0BC861AD276',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'BALTIMORE CITY',
#            '779'],
#           ['row-upwk-uby5_ytj9',
#            '00000000-0000-0000-CE87-62E05A657ED1',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'CALVERT',
#            '142'],
#           ['row-nbqr-kiht~bgr3',
#            '00000000-0000-0000-3271-348C6FAA9EA5',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'CAROLINE',
#            '7'],
#           ['row-rvxh.ggnt~epm4',
#            '00000000-0000-0000-76E5-DBEE1BDB1F16',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'CARROLL',
#            '300'],
#           ['row-z88t~pnfr_ujuy',
#            '00000000-0000-0000-DD81-8BC359EA4A5B',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'CECIL',
#            '85'],
#           ['row-7pmc-pimd_wrs3',
#            '00000000-0000-0000-BF9D-2ADAFE7B7203',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'CHARLES',
#            '205'],
#           ['row-w83w_yxyf~rbmq',
#            '00000000-0000-0000-E989-B51E9998E73F',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'DORCHESTER',
#            '24'],
#           ['row-mvdt~yrfg-nuhj',
#            '00000000-0000-0000-109D-59A3D1F0918D',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'FREDERICK',
#            '734'],
#           ['row-93mg.isnc.rqaq',
#            '00000000-0000-0000-8001-D4A563475942',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'GARRETT',
#            '15'],
#           ['row-3952_2krh_sqk8',
#            '00000000-0000-0000-3E7B-441BC1BACD83',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'HARFORD',
#            '329'],
#           ['row-xpam_buwk-xw9r',
#            '00000000-0000-0000-5619-85418DE4D12F',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'HOWARD',
#            '1979'],
#           ['row-wb9i_5fpb~uf6w',
#            '00000000-0000-0000-379F-C600923CD5CC',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'KENT',
#            '15'],
#           ['row-sqd6~3psd.b6k2',
#            '00000000-0000-0000-4455-7930AA624416',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'MONTGOMERY',
#            '5944'],
#           ['row-yit7.69db~3i7d',
#            '00000000-0000-0000-82AA-ED34A6C24F32',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'PRINCE GEORGES',
#            '1235'],
#           ['row-8kny~ijpp-469j',
#            '00000000-0000-0000-74E7-6459D64AF6F6',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'QUEEN ANNES',
#            '86'],
#           ['row-rghh_wnr7-3i3d',
#            '00000000-0000-0000-8B63-8A93BE899BC0',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'SAINT MARYS',
#            '152'],
#           ['row-evgk-g3au-cznu',
#            '00000000-0000-0000-AF8B-EB9F5C5501FB',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'SOMERSET',
#            '2'],
#           ['row-jpjm~58qe_ea93',
#            '00000000-0000-0000-CBB6-3B2F0BAC7F6C',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'TALBOT',
#            '71'],
#           ['row-nngj.w7x3.g7gt',
#            '00000000-0000-0000-5B31-1D053159C935',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'UNKNOWN',
#            '28'],
#           ['row-qagq_a283-bsmx',
#            '00000000-0000-0000-CEB4-2539D1601D44',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'WASHINGTON',
#            '138'],
#           ['row-wdxc~g6t3~n729',
#            '00000000-0000-0000-CB47-BFA9E180EF63',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'WICOMICO',
#            '52'],
#           ['row-47ya.sxnd~b49q',
#            '00000000-0000-0000-721E-8DE2BE0CB7C7',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'WORCESTER',
#            '47'],
#           ['row-vahf-43bd~p7f7',
#            '00000000-0000-0000-B1AE-E27F95C338D9',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'CA',
#            '2'],
#           ['row-e956-6xah.x3q4',
#            '00000000-0000-0000-8783-D129B985837C',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Electric',
#            'TX',
#            '1'],
#           ['row-yzc5-87j9.uxtb',
#            '00000000-0000-0000-E722-A364949ABA7E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'ALLEGANY',
#            '34'],
#           ['row-gcxr.b6gy-sgyh',
#            '00000000-0000-0000-D0FB-5066A659273E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'ANNE ARUNDEL',
#            '1138'],
#           ['row-5s62.a34v~ncvf',
#            '00000000-0000-0000-3CF5-6833771990A5',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'BALTIMORE',
#            '1242'],
#           ['row-689t~eeec_zgte',
#            '00000000-0000-0000-8F05-D794716C6273',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'BALTIMORE CITY',
#            '605'],
#           ['row-kjnq~6q9j-rcdc',
#            '00000000-0000-0000-BBB2-695B8D511837',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'CALVERT',
#            '160'],
#           ['row-t8tx_8uis-ce39',
#            '00000000-0000-0000-F04E-7EEA54614ED9',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'CAROLINE',
#            '19'],
#           ['row-ihgm_usjx.74ud',
#            '00000000-0000-0000-6EDA-5384CEF13250',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'CARROLL',
#            '235'],
#           ['row-yg3u-6vzp-exs3',
#            '00000000-0000-0000-C5A1-958AAD00C02E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'CECIL',
#            '75'],
#           ['row-v2au~eqd7~c88k',
#            '00000000-0000-0000-CAD8-916ED97A9C02',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'CHARLES',
#            '174'],
#           ['row-3bjm.s79b~zvbv',
#            '00000000-0000-0000-D906-13CC3EDFFD05',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'DORCHESTER',
#            '25'],
#           ['row-ky6r~72ty_dj82',
#            '00000000-0000-0000-9884-DF0038885723',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'FREDERICK',
#            '704'],
#           ['row-fze5_yu2s~5n2v',
#            '00000000-0000-0000-4349-F6C73B7F3017',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'GARRETT',
#            '5'],
#           ['row-ne36-qy29~vmzf',
#            '00000000-0000-0000-6F0A-EB2546B1152C',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'HARFORD',
#            '293'],
#           ['row-85cq-qn5f.h3b5',
#            '00000000-0000-0000-B8ED-2C2506ABA7B7',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'HOWARD',
#            '1155'],
#           ['row-4nyi_44nu~u6t5',
#            '00000000-0000-0000-122F-905A58B4B141',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'KENT',
#            '31'],
#           ['row-ade6-ymz3_jci7',
#            '00000000-0000-0000-CFDB-11B294314339',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'MONTGOMERY',
#            '3608'],
#           ['row-fkh7.3v23_cfyy',
#            '00000000-0000-0000-29EF-314A92DD911E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'PRINCE GEORGES',
#            '951'],
#           ['row-4385~sf92.zupc',
#            '00000000-0000-0000-B6E5-AFEACAC860A1',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'QUEEN ANNES',
#            '85'],
#           ['row-5yew~iyzk.4gjv',
#            '00000000-0000-0000-6508-4DA9D9B41FC2',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'SAINT MARYS',
#            '175'],
#           ['row-fk3f_brwb-vqcw',
#            '00000000-0000-0000-06EC-3D14EF68AC6B',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'SOMERSET',
#            '8'],
#           ['row-k3mc.54gs.kxt9',
#            '00000000-0000-0000-3A54-26E173487FA5',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'TALBOT',
#            '87'],
#           ['row-4if3_xr3v_vnev',
#            '00000000-0000-0000-AF02-58BCE29B8D78',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'UNKNOWN',
#            '18'],
#           ['row-hm7p~gygb_bbwq',
#            '00000000-0000-0000-1CD7-14C674037308',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'WASHINGTON',
#            '162'],
#           ['row-ddej_bvyu_hf9c',
#            '00000000-0000-0000-498E-53B1F32317CA',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'WICOMICO',
#            '89'],
#           ['row-nt3t_em84.vtth',
#            '00000000-0000-0000-35E6-810F4CBEF065',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'WORCESTER',
#            '63'],
#           ['row-89y7~ibh8-v7vd',
#            '00000000-0000-0000-6892-C16B89665386',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'CO',
#            '2'],
#           ['row-gnqu-3e9s~w5ku',
#            '00000000-0000-0000-181E-851F1714AAAF',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'DE',
#            '1'],
#           ['row-w47w-sxmq-xmat',
#            '00000000-0000-0000-E2B6-36F982CDCC2B',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'GA',
#            '1'],
#           ['row-pa7f.nt9x_je4k',
#            '00000000-0000-0000-DF9C-BCD3BC12791E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'IL',
#            '2'],
#           ['row-xxw6.krft_hct8',
#            '00000000-0000-0000-1E46-84788821915B',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'KY',
#            '1'],
#           ['row-knc7-t2c5~tisp',
#            '00000000-0000-0000-DCE4-56682F5E5138',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'NC',
#            '1'],
#           ['row-ahqe_6r7x.6rj7',
#            '00000000-0000-0000-88E5-8211CB7BC4DE',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'OH',
#            '2'],
#           ['row-2bns-tr8b_nbar',
#            '00000000-0000-0000-5E33-5D7A540456FE',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'TN',
#            '1'],
#           ['row-8dtq_2vcq_cew5',
#            '00000000-0000-0000-200B-12B97D53DB72',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/08',
#            'Plug-in Hybrid',
#            'WA',
#            '1'],
#           ['row-pupd_jaue.kggu',
#            '00000000-0000-0000-76B3-6B0832AAD3CD',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'ALLEGANY',
#            '35'],
#           ['row-m99f.cqwu.vm2w',
#            '00000000-0000-0000-D228-A50F35718E36',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'ANNE ARUNDEL',
#            '1658'],
#           ['row-uyk9-9rvc~8c7b',
#            '00000000-0000-0000-4A50-34D25ACD58FA',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'BALTIMORE',
#            '1587'],
#           ['row-f4kh.zkt5_gctq',
#            '00000000-0000-0000-3D71-4A3722D2897B',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'BALTIMORE CITY',
#            '804'],
#           ['row-85f5_fsye-y56e',
#            '00000000-0000-0000-9B73-1B1485C14FDE',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'CALVERT',
#            '148'],
#           ['row-2j9f_6wq2-rb2w',
#            '00000000-0000-0000-6541-77AC54E1CC02',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'CAROLINE',
#            '7'],
#           ['row-xcqp~kbsm~vb7k',
#            '00000000-0000-0000-F077-DAD54662C9AA',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'CARROLL',
#            '306'],
#           ['row-np6r.mrmu-gs9c',
#            '00000000-0000-0000-5F3E-BEF305FA6851',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'CECIL',
#            '88'],
#           ['row-y9rp_etma_5anr',
#            '00000000-0000-0000-3B1C-C39B4F39CC66',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'CHARLES',
#            '202'],
#           ['row-y92h~cs2q.j4pf',
#            '00000000-0000-0000-F67A-C6625CF3E4E3',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'DORCHESTER',
#            '24'],
#           ['row-pcb7.d8za_yxet',
#            '00000000-0000-0000-FE2F-438644A3B61D',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'FREDERICK',
#            '755'],
#           ['row-army.3vqj~ujdj',
#            '00000000-0000-0000-29D5-5C5D40958228',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'GARRETT',
#            '17'],
#           ['row-ieg4_mhbr-jkxr',
#            '00000000-0000-0000-C6EB-FD8DEB04C455',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'HARFORD',
#            '341'],
#           ['row-gzkz_xx4v~a2jh',
#            '00000000-0000-0000-36B8-D7670C71B420',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'HOWARD',
#            '2014'],
#           ['row-q9sx_nkvu.djgq',
#            '00000000-0000-0000-613C-F7225AF4FB9F',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'KENT',
#            '13'],
#           ['row-mgg2_dh2z-wekn',
#            '00000000-0000-0000-FBA4-FC9B354C47A6',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'MONTGOMERY',
#            '6040'],
#           ['row-vq5y-j8g4.f73r',
#            '00000000-0000-0000-811A-33B6C775DC4C',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'PRINCE GEORGES',
#            '1264'],
#           ['row-yqv4-d228.kdxf',
#            '00000000-0000-0000-5A29-893D8BE57AAC',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'QUEEN ANNES',
#            '87'],
#           ['row-xryc~7tks~b7fp',
#            '00000000-0000-0000-218E-0FEC8FCA9812',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'SAINT MARYS',
#            '154'],
#           ['row-hhph.88cx~igtn',
#            '00000000-0000-0000-777E-EE43F57EA73E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'SOMERSET',
#            '3'],
#           ['row-pae8-7kd5-xpya',
#            '00000000-0000-0000-4043-3EF924675DA8',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'TALBOT',
#            '73'],
#           ['row-9n2j~ckby.95ey',
#            '00000000-0000-0000-9EE2-03DE23B88DD9',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'UNKNOWN',
#            '27'],
#           ['row-rday_pnky.7tem',
#            '00000000-0000-0000-D3CF-1D8D731164F1',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'WASHINGTON',
#            '138'],
#           ['row-dysn~irtr_spmu',
#            '00000000-0000-0000-A3D5-447B36B8FC30',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'WICOMICO',
#            '55'],
#           ['row-bf8p-9nbu.dksf',
#            '00000000-0000-0000-F2BA-239F4722F2A2',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'WORCESTER',
#            '46'],
#           ['row-qdkk-bfn8-djhg',
#            '00000000-0000-0000-D440-1F8A2F17E848',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'CA',
#            '2'],
#           ['row-mu67~n8tv~c7w7',
#            '00000000-0000-0000-2A9C-B2C0666FCE0E',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Electric',
#            'TX',
#            '1'],
#           ['row-277m-t76r.g822',
#            '00000000-0000-0000-1685-0FFC874A0CFE',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'ALLEGANY',
#            '37'],
#           ['row-gbug.j2sq_qwha',
#            '00000000-0000-0000-3DD5-C1C77969D3B7',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'ANNE ARUNDEL',
#            '1152'],
#           ['row-mwgq~7w32_h24p',
#            '00000000-0000-0000-A20C-2D9E409B7EC3',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'BALTIMORE',
#            '1259'],
#           ['row-y9zm-jf4i_rnka',
#            '00000000-0000-0000-5976-94B8DF923D96',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'BALTIMORE CITY',
#            '624'],
#           ['row-qea5.7ubt_rbqm',
#            '00000000-0000-0000-65DE-33E0BB62822C',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'CALVERT',
#            '165'],
#           ['row-ig37_m2wi.ptex',
#            '00000000-0000-0000-7846-8DF7779FFAF3',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'CAROLINE',
#            '19'],
#           ['row-z3f7_f6ti-c3bu',
#            '00000000-0000-0000-8933-B7F00DA1001D',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'CARROLL',
#            '240'],
#           ['row-f2ma~jctg~7dc9',
#            '00000000-0000-0000-E51D-B9267B9E7CB9',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'CECIL',
#            '76'],
#           ['row-s9xs.tg52_qgtn',
#            '00000000-0000-0000-7274-08D538E8FC02',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'CHARLES',
#            '176'],
#           ['row-k6hr-hfmi.3hj4',
#            '00000000-0000-0000-F4CA-4B684D8C0925',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'DORCHESTER',
#            '26'],
#           ['row-4zp4~shb7_ie64',
#            '00000000-0000-0000-13C2-FCD875BBE91D',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'FREDERICK',
#            '703'],
#           ['row-325q.8gf9-id6d',
#            '00000000-0000-0000-7277-A1E4B3DAB04C',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'GARRETT',
#            '6'],
#           ['row-muih_y7id~3gw7',
#            '00000000-0000-0000-0C2D-7FC5ED54E818',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'HARFORD',
#            '298'],
#           ['row-x7ds.nasc~wj7j',
#            '00000000-0000-0000-DDEB-0D46BEE30944',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'HOWARD',
#            '1158'],
#           ['row-jgaa.v52g-tm68',
#            '00000000-0000-0000-20FA-7F7AAB1EEE86',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'KENT',
#            '35'],
#           ['row-friy-5cyt_ssfq',
#            '00000000-0000-0000-B412-38F268903AF4',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'MONTGOMERY',
#            '3664'],
#           ['row-d9v5.i3bx.hhst',
#            '00000000-0000-0000-4EB5-D66AAB4B924F',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'PRINCE GEORGES',
#            '955'],
#           ['row-7t2e~2xmw.q5ru',
#            '00000000-0000-0000-BDE3-EDC12A53AB97',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'QUEEN ANNES',
#            '87'],
#           ['row-xhaw~8h5d_cqru',
#            '00000000-0000-0000-6FF9-6CE18D812293',
#            0,
#            1686936004,
#            None,
#            1686936004,
#            None,
#            '{ }',
#            '2020/09',
#            'Plug-in Hybrid',
#            'SAINT MARYS',
#            '174'],
#           ['row-fpef~4e2m_ms7v',
# ...
#                                                    'smallest': 'AE',
#                                                    'top': [{'count_1': '70',
#                                                             'item': 'MONTGOMERY'},
#                                                            {'count_1': '70',
#                                                             'item': 'WORCESTER'},
#                                                            {'count_1': '70',
#                                                             'item': 'WICOMICO'},
#                                                            {'count_1': '70',
#                                                             'item': 'ALLEGANY'},
#                                                            {'count_1': '70',
#                                                             'item': 'ANNE '
#                                                                     'ARUNDEL'},
#                                                            {'count_1': '70',
#                                                             'item': 'WASHINGTON'},
#                                                            {'count_1': '70',
#                                                             'item': 'CALVERT'},
#                                                            {'count_1': '70',
#                                                             'item': 'CAROLINE'},
#                                                            {'count_1': '70',
#                                                             'item': 'CARROLL'},
#                                                            {'count_1': '70',
#                                                             'item': 'CECIL'},
#                                                            {'count_1': '70',
#                                                             'item': 'CHARLES'},
#                                                            {'count_1': '70',
#                                                             'item': 'DORCHESTER'},
#                                                            {'count_1': '70',
#                                                             'item': 'FREDERICK'},
#                                                            {'count_1': '70',
#                                                             'item': 'GARRETT'},
#                                                            {'count_1': '70',
#                                                             'item': 'HARFORD'},
#                                                            {'count_1': '70',
#                                                             'item': 'HOWARD'},
#                                                            {'count_1': '70',
#                                                             'item': 'TALBOT'},
#                                                            {'count_1': '70',
#                                                             'item': 'SOMERSET'},
#                                                            {'count_1': '70',
#                                                             'item': 'KENT'},
#                                                            {'count_1': '70',
#                                                             'item': 'SAINT '
#                                                                     'MARYS'}]},
#                                 'dataTypeName': 'text',
#                                 'description': 'County of residence',
#                                 'fieldName': 'county',
#                                 'format': {},
#                                 'id': 513230936,
#                                 'name': 'County',
#                                 'position': 3,
#                                 'renderTypeName': 'text',
#                                 'tableColumnId': 77267841},
#                                {'cachedContents': {'count': '2838',
#                                                    'largest': '16125',
#                                                    'non_null': '2838',
#                                                    'null': '0',
#                                                    'smallest': '1',
#                                                    'top': [{'count_1': '378',
#                                                             'item': '1'},
#                                                            {'count_1': '171',
#                                                             'item': '2'},
#                                                            {'count_1': '104',
#                                                             'item': '3'},
#                                                            {'count_1': '59',
#                                                             'item': '4'},
#                                                            {'count_1': '53',
#                                                             'item': '5'},
#                                                            {'count_1': '42',
#                                                             'item': '6'},
#                                                            {'count_1': '34',
#                                                             'item': '8'},
#                                                            {'count_1': '30',
#                                                             'item': '7'},
#                                                            {'count_1': '29',
#                                                             'item': '19'},
#                                                            {'count_1': '28',
#                                                             'item': '12'},
#                                                            {'count_1': '27',
#                                                             'item': '11'},
#                                                            {'count_1': '24',
#                                                             'item': '18'},
#                                                            {'count_1': '20',
#                                                             'item': '9'},
#                                                            {'count_1': '19',
#                                                             'item': '16'},
#                                                            {'count_1': '19',
#                                                             'item': '39'},
#                                                            {'count_1': '18',
#                                                             'item': '26'},
#                                                            {'count_1': '18',
#                                                             'item': '10'},
#                                                            {'count_1': '17',
#                                                             'item': '15'},
#                                                            {'count_1': '16',
#                                                             'item': '14'},
#                                                            {'count_1': '15',
#                                                             'item': '13'}]},
#                                 'dataTypeName': 'number',
#                                 'description': '',
#                                 'fieldName': 'count',
#                                 'format': {},
#                                 'id': 513230937,
#                                 'name': 'Count',
#                                 'position': 4,
#                                 'renderTypeName': 'number',
#                                 'tableColumnId': 77267842}],
#                    'createdAt': 1551118512,
#                    'description': 'Total number of electric and plug-in hybrid '
#                                   'vehicles with active MD registrations by '
#                                   'county as of each month end from July 2020 '
#                                   'to May 2023',
#                    'displayType': 'table',
#                    'downloadCount': 2275,
#                    'flags': ['default',
#                              'ownerMayBeContacted',
#                              'restorable',
#                              'restorePossibleForType'],
#                    'grants': [{'flags': ['public'],
#                                'inherited': False,
#                                'type': 'viewer'}],
#                    'hideFromCatalog': False,
#                    'hideFromDataJson': False,
#                    'id': 'qtcv-n3tc',
#                    'metadata': {'availableDisplayTypes': ['table',
#                                                           'fatrow',
#                                                           'page'],
#                                 'custom_fields': {'Agency': {'State Agency Performing Data Updates': 'Maryland '
#                                                                                                      'Department '
#                                                                                                      'of '
#                                                                                                      'Transportation'},
#                                                   'GIS Download': {'Place Keywords': 'Maryland, '
#                                                                                      'County, '
#                                                                                      'Baltimore '
#                                                                                      'City, '
#                                                                                      'Allegany, '
#                                                                                      'Anne '
#                                                                                      'Arundel, '
#                                                                                      'Baltimore, '
#                                                                                      'Calvert, '
#                                                                                      'Caroline, '
#                                                                                      'Carroll, '
#                                                                                      'Cecil, '
#                                                                                      'Charles, '
#                                                                                      'Dorchester, '
#                                                                                      'Frederick, '
#                                                                                      'Garrett, '
#                                                                                      'Harford, '
#                                                                                      'Howard, '
#                                                                                      'Kent, '
#                                                                                      'Montgomery, '
#                                                                                      'Prince '
#                                                                                      "George's, "
#                                                                                      'Queen '
#                                                                                      "Anne's, "
#                                                                                      'St '
#                                                                                      "Mary's, "
#                                                                                      'Somerset, '
#                                                                                      'Talbot, '
#                                                                                      'Washington, '
#                                                                                      'Wicomico, '
#                                                                                      'Worcester\t\t\t\t\t\t\t\t\t'},
#                                                   'Jurisdiction': {'Jurisdiction': 'State '
#                                                                                    'of '
#                                                                                    'Maryland'},
#                                                   'Time Period': {'Date Metadata Written': 'June '
#                                                                                            '16, '
#                                                                                            '2023',
#                                                                   'Time Period of Content': 'As '
#                                                                                             'of '
#                                                                                             'May '
#                                                                                             '2023',
#                                                                   'Update Frequency': 'Monthly'}},
#                                 'rowLabel': 'Electric or Plug-In Hybrid '
#                                             'vehicle registrations by county '
#                                             'with counts.  If we are not able '
#                                             'to match vehicle registrations to '
#                                             'a county, the records will be '
#                                             "assigned to 'unknown' in the "
#                                             'county column.'},
#                    'name': 'MDOT/MVA Electric and Plug-in Hybrid Vehicle '
#                            'Registrations by County as of each month end from '
#                            'July 2020 to May 2023',
#                    'newBackend': True,
#                    'numberOfComments': 0,
#                    'oid': 35948141,
#                    'owner': {'displayName': 'Christine Howard',
#                              'flags': ['acceptedEula'],
#                              'id': '6ayz-q2pi',
#                              'screenName': 'Christine Howard',
#                              'type': 'interactive'},
#                    'provenance': 'official',
#                    'publicationAppendEnabled': False,
#                    'publicationDate': 1607538204,
#                    'publicationGroup': 15988668,
#                    'publicationStage': 'published',
#                    'query': {},
#                    'rights': ['read'],
#                    'rowsUpdatedAt': 1686936004,
#                    'rowsUpdatedBy': '6ayz-q2pi',
#                    'tableAuthor': {'displayName': 'Christine Howard',
#                                    'flags': ['acceptedEula'],
#                                    'id': '6ayz-q2pi',
#                                    'screenName': 'Christine Howard',
#                                    'type': 'interactive'},
#                    'tableId': 17848893,
#                    'tags': ['mva',
#                             'ev',
#                             'electric vehicle',
#                             'vehicle',
#                             'car',
#                             'auto',
#                             'trucks',
#                             'registrations',
#                             'maryland mva',
#                             'hybrid vehicle',
#                             'hybrid',
#                             'plugin',
#                             'plug-in',
#                             'plug-in hybrid'],
#                    'totalTimesRated': 0,
#                    'viewCount': 5070,
#                    'viewLastModified': 1686936003,
#                    'viewType': 'tabular'}}}

# %%
# assign the collection to a variable
establishments = db['project3']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Out:
# Inserted document ID: 64ac75fb6e4d21d7c77f5c12

# %%
# Check that the new restaurant was inserted
# Print the inserted document's ObjectId
print("Inserted document ID:", result.inserted_id)
# Out:
# Inserted document ID: 64ac75fb6e4d21d7c77f5c12

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
# Define the query and projection
query = {"BusinessType": "Restaurant/Cafe/Canteen"}
projection = {"BusinessTypeID": 1, "BusinessType": 1, "_id": 0}

# Find the matching documents and display the results
cursor = collection.find(query, projection)
for document in cursor:
    pprint(document)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
# Define the query to match the "Penang Flavours" restaurant
query = {"name": "Penang Flavours"}

# Define the update operation to set the BusinessTypeID
update = {"$set": {"BusinessTypeID": "1"}}

# Update the document with the correct BusinessTypeID
result = collection.update_one(query, update)

# %%
# Confirm that the new restaurant was updated
# Print the number of documents matched and modified
print("Matched documents:", result.matched_count)
print("Modified documents:", result.modified_count)
# Out:
# Matched documents: 1
# Modified documents: 1

# %%
# Define the query to match the "Penang Flavours" restaurant
query = {"name": "Penang Flavours"}

# Retrieve and display the updated document
document = collection.find_one(query)
pprint(document)
# Out:
# {'BusinessTypeID': '1',
#  '_id': ObjectId('64ac75fb6e4d21d7c77f5c12'),
#  'address': 'Greenwich',
#  'cuisine': 'Halal',
#  'name': 'Penang Flavours',
#  'rating': None}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {"LocalAuthorityName": "Dover"}

# Count the number of documents matching the query
count = collection.count_documents(query)

# Print the count of documents with LocalAuthorityName as "Dover"
print("Number of documents with LocalAuthorityName as 'Dover':", count)
# Out:
# Number of documents with LocalAuthorityName as 'Dover': 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {"LocalAuthorityName": "Dover"}

# Delete the documents matching the query
result = collection.delete_many(query)

# Print the number of deleted documents
print("Number of documents deleted:", result.deleted_count)
# Out:
# Number of documents deleted: 994

# %%
query = {"LocalAuthorityName": "Dover"}

# Count the number of documents matching the query
count = collection.count_documents(query)

# Check if any documents are found
if count > 0:
    print("There are still documents with LocalAuthorityName as 'Dover'.")
else:
    print("No documents found with LocalAuthorityName as 'Dover'.")
# Out:
# No documents found with LocalAuthorityName as 'Dover'.

# %%
# Check that other documents remain with 'find_one'
collection = db["establishments"]

# Find and display one document from the establishments collection
document = collection.find_one()
pprint(document)
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64ac48994851275aaa060a04'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
# Update the data type of longitude and latitude fields
result = collection.update_many({}, [
    {"$set": {"longitude": {"$toDecimal": "$longitude"}}},
    {"$set": {"latitude": {"$toDecimal": "$latitude"}}}
])

# Print the number of modified documents
print("Modified documents:", result.modified_count)
# Out:
# Modified documents: 0

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
collection = db["establishments"]

# Define the non-rating values
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]

# Update RatingValue to integers and set non 1-5 ratings to null
result = collection.update_many(
    {"RatingValue": {"$in": non_ratings}},
    [{"$set": {"RatingValue": {"$toInt": {"$cond": [{"$in": ["$RatingValue", non_ratings]}, None, "$RatingValue"]}}}}]
)

# Print the number of modified documents
print("Modified documents:", result.modified_count)
# Out:
# Modified documents: 4091

# %%
# Check that the coordinates and rating value are now numbers
# Find and display one document from the establishments collection
document = collection.find_one()

# Check the data type of the longitude, latitude, and RatingValue fields
print("Longitude data type:", type(document["longitude"]))
print("Latitude data type:", type(document["latitude"]))
print("RatingValue data type:", type(document["RatingValue"]))
# Out:
# Longitude data type: <class 'NoneType'>
# Latitude data type: <class 'NoneType'>
# RatingValue data type: <class 'int'>
